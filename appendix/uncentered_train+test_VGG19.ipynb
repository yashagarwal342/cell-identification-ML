# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# CONFIG
BASE_DIR = "uncentered"
TEMP_TRAIN_DIR = "temp_train_uncentered"
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 5  # increase if needed
SEED = 42
CLASS_NAMES = ['Empty', 'Non-tumor', 'Tumor']
QUADRANTS = ['Q1', 'Q2', 'Q3', 'Q4']

# UTILITY FUNCTION: Prepare training folder by combining 3 quadrants
def prepare_train_dir(exclude_quad):
    if os.path.exists(TEMP_TRAIN_DIR):
        shutil.rmtree(TEMP_TRAIN_DIR)
    os.makedirs(TEMP_TRAIN_DIR)

    for cls in CLASS_NAMES:
        os.makedirs(os.path.join(TEMP_TRAIN_DIR, cls))

    for quad in QUADRANTS:
        if quad == exclude_quad:
            continue
        quad_path = os.path.join(BASE_DIR, quad)
        for cls in CLASS_NAMES:
            src = os.path.join(quad_path, cls)
            dst = os.path.join(TEMP_TRAIN_DIR, cls)
            for file in os.listdir(src):
                shutil.copy(os.path.join(src, file), os.path.join(dst, file))

# PLOT LOSS & ACCURACY
def plot_training(history, fold):
    plt.figure(figsize=(10, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.title(f'Fold {fold}: Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'Fold {fold}: Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# CONFUSION MATRIX
def show_confusion_matrix(y_true, y_pred, fold):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title(f'Fold {fold}: Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# MAIN LOOP
for i, test_quad in enumerate(QUADRANTS, start=1):
    print(f"\n🟨 Fold {i} - Test Quadrant: {test_quad}")

    prepare_train_dir(test_quad)

    # Data generators
    datagen = ImageDataGenerator(rescale=1./255, validation_split=0.25)

    train_gen = datagen.flow_from_directory(
        TEMP_TRAIN_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='training',
        shuffle=True,
        seed=SEED
    )

    val_gen = datagen.flow_from_directory(
        TEMP_TRAIN_DIR,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='validation',
        shuffle=True,
        seed=SEED
    )

    test_gen = ImageDataGenerator(rescale=1./255).flow_from_directory(
        os.path.join(BASE_DIR, test_quad),
        target_size=IMAGE_SIZE,
        batch_size=1,
        class_mode='categorical',
        shuffle=False
    )

    # VGG19 model
    base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False

    model = Sequential([
        base_model,
        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(3, activation='softmax')
    ])

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

    # Train
    history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)

    # Plot training
    plot_training(history, i)

    # Evaluate on test set
    test_gen.reset()
    preds = model.predict(test_gen)
    y_pred = np.argmax(preds, axis=1)
    y_true = test_gen.classes

    print(f"📊 Classification Report for Fold {i}")
    print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))

    show_confusion_matrix(y_true, y_pred, i)

# Cleanup
shutil.rmtree(TEMP_TRAIN_DIR)
# Out:
# 🟨 Fold 1 - Test Quadrant: Q1
# Found 2475 images belonging to 3 classes.
# Found 825 images belonging to 3 classes.
# Found 1100 images belonging to 3 classes.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/5
# 78/78 [==============================] - 7379s 95s/step - loss: 0.9175 - accuracy: 0.7422 - val_loss: 0.4897 - val_accuracy: 0.8024
# Epoch 2/5
# 78/78 [==============================] - 3888s 50s/step - loss: 0.4351 - accuracy: 0.8238 - val_loss: 0.4647 - val_accuracy: 0.7964
# Epoch 3/5
# 78/78 [==============================] - 7791s 101s/step - loss: 0.3987 - accuracy: 0.8380 - val_loss: 0.4711 - val_accuracy: 0.8145
# Epoch 4/5
# 78/78 [==============================] - 2433s 31s/step - loss: 0.3792 - accuracy: 0.8533 - val_loss: 0.4480 - val_accuracy: 0.8218
# Epoch 5/5
# 78/78 [==============================] - 2427s 31s/step - loss: 0.3499 - accuracy: 0.8642 - val_loss: 0.5306 - val_accuracy: 0.8048
# 1100/1100 [==============================] - 786s 714ms/step
# 📊 Classification Report for Fold 1
#               precision    recall  f1-score   support
#
#        Empty       1.00      0.81      0.90       100
#    Non-tumor       0.83      0.91      0.87       500
#        Tumor       0.90      0.85      0.88       500
#
#     accuracy                           0.87      1100
#    macro avg       0.91      0.86      0.88      1100
# weighted avg       0.88      0.87      0.87      1100
# 🟨 Fold 2 - Test Quadrant: Q2
# Found 2475 images belonging to 3 classes.
# Found 825 images belonging to 3 classes.
# Found 1100 images belonging to 3 classes.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/5
# 78/78 [==============================] - 2405s 31s/step - loss: 0.8078 - accuracy: 0.7749 - val_loss: 0.6945 - val_accuracy: 0.7127
# Epoch 2/5
# 78/78 [==============================] - 1655s 21s/step - loss: 0.3769 - accuracy: 0.8481 - val_loss: 0.5815 - val_accuracy: 0.7467
# Epoch 3/5
# 78/78 [==============================] - 1623s 21s/step - loss: 0.3438 - accuracy: 0.8614 - val_loss: 0.6655 - val_accuracy: 0.7079
# Epoch 4/5
# 78/78 [==============================] - 1659s 21s/step - loss: 0.3162 - accuracy: 0.8796 - val_loss: 0.6179 - val_accuracy: 0.7491
# Epoch 5/5
# 78/78 [==============================] - 1584s 20s/step - loss: 0.2997 - accuracy: 0.8828 - val_loss: 0.7082 - val_accuracy: 0.7188
# 1100/1100 [==============================] - 518s 471ms/step
# 📊 Classification Report for Fold 2
#               precision    recall  f1-score   support
#
#        Empty       0.80      1.00      0.89       100
#    Non-tumor       0.87      0.81      0.84       500
#        Tumor       0.86      0.88      0.87       500
#
#     accuracy                           0.86      1100
#    macro avg       0.84      0.90      0.87      1100
# weighted avg       0.86      0.86      0.86      1100
# 🟨 Fold 3 - Test Quadrant: Q3
# Found 2475 images belonging to 3 classes.
# Found 825 images belonging to 3 classes.
# Found 1100 images belonging to 3 classes.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/5
# 78/78 [==============================] - 1630s 21s/step - loss: 1.4284 - accuracy: 0.7414 - val_loss: 0.4094 - val_accuracy: 0.8073
# Epoch 2/5
# 78/78 [==============================] - 1604s 21s/step - loss: 0.3735 - accuracy: 0.8521 - val_loss: 0.3905 - val_accuracy: 0.8400
# Epoch 3/5
# 78/78 [==============================] - 1606s 21s/step - loss: 0.3392 - accuracy: 0.8642 - val_loss: 0.3913 - val_accuracy: 0.8339
# Epoch 4/5
# 78/78 [==============================] - 1599s 21s/step - loss: 0.3335 - accuracy: 0.8695 - val_loss: 0.3821 - val_accuracy: 0.8364
# Epoch 5/5
# 78/78 [==============================] - 1591s 20s/step - loss: 0.3023 - accuracy: 0.8848 - val_loss: 0.4132 - val_accuracy: 0.8182
# 1100/1100 [==============================] - 515s 468ms/step
# 📊 Classification Report for Fold 3
#               precision    recall  f1-score   support
#
#        Empty       0.83      0.71      0.76       100
#    Non-tumor       0.86      0.66      0.74       500
#        Tumor       0.75      0.95      0.84       500
#
#     accuracy                           0.79      1100
#    macro avg       0.81      0.77      0.78      1100
# weighted avg       0.81      0.79      0.79      1100
# 🟨 Fold 4 - Test Quadrant: Q4
# Found 2475 images belonging to 3 classes.
# Found 825 images belonging to 3 classes.
# Found 1100 images belonging to 3 classes.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/5
# 78/78 [==============================] - 1607s 21s/step - loss: 0.8732 - accuracy: 0.8073 - val_loss: 0.6274 - val_accuracy: 0.7212
# Epoch 2/5
# 78/78 [==============================] - 1716s 22s/step - loss: 0.3391 - accuracy: 0.8663 - val_loss: 0.5902 - val_accuracy: 0.7503
# Epoch 3/5
# 78/78 [==============================] - 1747s 22s/step - loss: 0.2973 - accuracy: 0.8893 - val_loss: 0.5709 - val_accuracy: 0.7394
# Epoch 4/5
# 78/78 [==============================] - 1758s 23s/step - loss: 0.2776 - accuracy: 0.8877 - val_loss: 0.6877 - val_accuracy: 0.7442
# Epoch 5/5
# 78/78 [==============================] - 1962s 25s/step - loss: 0.2526 - accuracy: 0.9042 - val_loss: 0.7314 - val_accuracy: 0.7333
# 1100/1100 [==============================] - 336s 306ms/step
# 📊 Classification Report for Fold 4
#               precision    recall  f1-score   support
#
#        Empty       0.78      0.99      0.87       100
#    Non-tumor       0.81      0.86      0.83       500
#        Tumor       0.89      0.79      0.84       500
#
#     accuracy                           0.84      1100
#    macro avg       0.83      0.88      0.85      1100
# weighted avg       0.84      0.84      0.84      1100
